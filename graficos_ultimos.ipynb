# %% [markdown]
# ## Los dos graficos a continuacion representan datos de ESCENARIO 10 NODOS MAX_MIN

# %%
import matplotlib.pyplot as plt
import numpy as np
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro
# Data provided by the user
costo_convergencia = [
    43.85678346, 42.35713939, 43.81113356, 43.71124275,
    40.8948863, 46.96839233, 43.55320452, 41.39695943,
    41.74531327, 41.03445549
]

mejor_costo = [
    43.81015348, 41.19846524, 41.42907402, 41.31965947,
    40.8948863, 44.13689655, 43.55320452, 41.31965947,
    41.74531327, 41.03445549
]
# Calcular los promedios
promedio_costo_convergencia = np.mean(costo_convergencia)
promedio_mejor_costo = np.mean(mejor_costo)

# Labels for the x-axis
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Create a bar chart
fig, ax = plt.subplots(figsize=(15, 8))

# Set the width for better spacing
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, costo_convergencia, width, label='Costo Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, mejor_costo, width, label='Mejor Costo', color=light_orange_hex)

# Set labels and title
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Costo', fontsize=14)
ax.set_title('Costo de Convergencia vs Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Set y-axis limits to display from 20 to 50
ax.set_ylim(35, 50)

# Add the horizontal lines for averages with increased thickness
ax.axhline(y=promedio_costo_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Costo Convergencia')
ax.axhline(y=promedio_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define los códigos de color HEX para naranja oscuro y naranja claro
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro

# Datos proporcionados por el usuario para las iteraciones
iteracion_convergencia = [17,4,8,2,76,6,64,4,16,34]
iteracion_mejor_costo = [68,47,91,78,76,65,64,70,16,34]

# Calcular los promedios
promedio_iteracion_convergencia = np.mean(iteracion_convergencia)
promedio_iteracion_mejor_costo = np.mean(iteracion_mejor_costo)

# Etiquetas para el eje x
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Crear un gráfico de barras
fig, ax = plt.subplots(figsize=(15, 8))

# Establecer el ancho para un mejor espaciado
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, iteracion_convergencia, width, label='Iteración Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, iteracion_mejor_costo, width, label='Iteración Mejor Costo', color=light_orange_hex)

# Configurar etiquetas y título
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Número de Iteraciones', fontsize=14)
ax.set_title('Iteración de Convergencia vs Iteración de Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Establecer los límites del eje y
ax.set_ylim(0, 100)

# Añadir líneas horizontales para los promedios con mayor grosor
ax.axhline(y=promedio_iteracion_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Iteración Convergencia')
ax.axhline(y=promedio_iteracion_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Iteración Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Los dos graficos a continuacion representan datos de ESCENARIO 20 NODOS MAX_MIN

# %%
import matplotlib.pyplot as plt
import numpy as np
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro
# Data provided by the user

costo_convergencia = [
    66.8916228619114, 70.2629673155429, 73.067496816054, 67.7836073590044, 67.4483222429732, 69.7901738416642, 70.3635531349863, 65.7497705718832,70.5599347565884, 70.70110964

]


mejor_costo = [
    66.4591217675976, 66.7224716055087, 72.1499864868365, 67.7836073590044, 67.4483222429732, 68.6533713232504, 69.6012530355149, 64.8727645221442, 68.6418281231366, 69.5418466392849
]
# Calcular los promedios
promedio_costo_convergencia = np.mean(costo_convergencia)
promedio_mejor_costo = np.mean(mejor_costo)
# Labels for the x-axis
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Create a bar chart
fig, ax = plt.subplots(figsize=(15, 8))

# Set the width for better spacing
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, costo_convergencia, width, label='Costo Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, mejor_costo, width, label='Mejor Costo', color=light_orange_hex)

# Set labels and title
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Costo', fontsize=14)
ax.set_title('Costo de Convergencia vs Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Set y-axis limits to display from 20 to 50
ax.set_ylim(55, 75)

# Add the horizontal lines for averages with increased thickness
ax.axhline(y=promedio_costo_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Costo Convergencia')
ax.axhline(y=promedio_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define los códigos de color HEX para naranja oscuro y naranja claro
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro

# Datos proporcionados por el usuario para las iteraciones
iteracion_convergencia = [40,48,45,41,51,32,27,68,27,21]
iteracion_mejor_costo = [50,85,72,41,51,59,47,98,69,35]

# Calcular los promedios
promedio_iteracion_convergencia = np.mean(iteracion_convergencia)
promedio_iteracion_mejor_costo = np.mean(iteracion_mejor_costo)

# Etiquetas para el eje x
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Crear un gráfico de barras
fig, ax = plt.subplots(figsize=(15, 8))

# Establecer el ancho para un mejor espaciado
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, iteracion_convergencia, width, label='Iteración Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, iteracion_mejor_costo, width, label='Iteración Mejor Costo', color=light_orange_hex)

# Configurar etiquetas y título
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Número de Iteraciones', fontsize=14)
ax.set_title('Iteración de Convergencia vs Iteración de Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Establecer los límites del eje y
ax.set_ylim(0, 125)

# Añadir líneas horizontales para los promedios con mayor grosor
ax.axhline(y=promedio_iteracion_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Iteración Convergencia')
ax.axhline(y=promedio_iteracion_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Iteración Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Los dos graficos a continuacion representan datos de ESCENARIO 30 NODOS MAX_MIN

# %%
import matplotlib.pyplot as plt
import numpy as np
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro
# Data provided by the user

costo_convergencia = [
    129.23951707999, 134.048239659229, 125.980895402647, 125.603307047864, 125.404727494798, 129.810925372358, 132.185777485887, 131.713578823942, 131.614631363646, 126.969284245861
]

mejor_costo = [
    129.23951707999, 133.749818560181, 125.980895402647, 123.602402144011, 125.404727494798, 126.64616842783, 129.188532413621, 125.679425492663, 131.614631363646, 126.969284245861
]
# Calcular los promedios
promedio_costo_convergencia = np.mean(costo_convergencia)
promedio_mejor_costo = np.mean(mejor_costo)
# Labels for the x-axis
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Create a bar chart
fig, ax = plt.subplots(figsize=(15, 8))

# Set the width for better spacing
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, costo_convergencia, width, label='Costo Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, mejor_costo, width, label='Mejor Costo', color=light_orange_hex)

# Set labels and title
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Costo', fontsize=14)
ax.set_title('Costo de Convergencia vs Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Set y-axis limits to display from 20 to 50
ax.set_ylim(120, 140)

# Add the horizontal lines for averages with increased thickness
ax.axhline(y=promedio_costo_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Costo Convergencia')
ax.axhline(y=promedio_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define los códigos de color HEX para naranja oscuro y naranja claro
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro

# Datos proporcionados por el usuario para las iteraciones
iteracion_convergencia = [16,12,53,6,33,2,27,3,14,28]
iteracion_mejor_costo = [16,31,53,50,33,95,57,54,14,28]

# Calcular los promedios
promedio_iteracion_convergencia = np.mean(iteracion_convergencia)
promedio_iteracion_mejor_costo = np.mean(iteracion_mejor_costo)

# Etiquetas para el eje x
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Crear un gráfico de barras
fig, ax = plt.subplots(figsize=(15, 8))

# Establecer el ancho para un mejor espaciado
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, iteracion_convergencia, width, label='Iteración Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, iteracion_mejor_costo, width, label='Iteración Mejor Costo', color=light_orange_hex)

# Configurar etiquetas y título
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Número de Iteraciones', fontsize=14)
ax.set_title('Iteración de Convergencia vs Iteración de Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Establecer los límites del eje y
ax.set_ylim(0, 100)

# Añadir líneas horizontales para los promedios con mayor grosor
ax.axhline(y=promedio_iteracion_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Iteración Convergencia')
ax.axhline(y=promedio_iteracion_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Iteración Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Los dos graficos a continuacion representan datos de ESCENARIO 10 NODOS ACO CON DRON

# %%
import matplotlib.pyplot as plt
import numpy as np
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro
# Data provided by the user

costo_convergencia = [
    41.54859742, 41.56784923, 42.1462400092488, 41.8572880674834, 41.337615459742, 43.065140604603, 42.2826923549452, 42.0006993001786, 39.0554467259991, 41.27957966

]


mejor_costo = [
    41.33761546,
41.41154023,
41.03445549,
41.40619194,
41.18394985,
41.42907402,
41.33761546,
41.939591,
39.05544673,
41.27957966
]
# Calcular los promedios
promedio_costo_convergencia = np.mean(costo_convergencia)
promedio_mejor_costo = np.mean(mejor_costo)
# Labels for the x-axis
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Create a bar chart
fig, ax = plt.subplots(figsize=(15, 8))

# Set the width for better spacing
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, costo_convergencia, width, label='Costo Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, mejor_costo, width, label='Mejor Costo', color=light_orange_hex)

# Set labels and title
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Costo', fontsize=14)
ax.set_title('Costo de Convergencia vs Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Set y-axis limits to display from 20 to 50
ax.set_ylim(38, 44)

# Add the horizontal lines for averages with increased thickness
ax.axhline(y=promedio_costo_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Costo Convergencia')
ax.axhline(y=promedio_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define los códigos de color HEX para naranja oscuro y naranja claro
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro

# Datos proporcionados por el usuario para las iteraciones
iteracion_convergencia = [60,60,11,47,32,0,16,17,21,4]
iteracion_mejor_costo = [76,62,79,77,77,73,90,42,21,4]

# Calcular los promedios
promedio_iteracion_convergencia = np.mean(iteracion_convergencia)
promedio_iteracion_mejor_costo = np.mean(iteracion_mejor_costo)

# Etiquetas para el eje x
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Crear un gráfico de barras
fig, ax = plt.subplots(figsize=(15, 8))

# Establecer el ancho para un mejor espaciado
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, iteracion_convergencia, width, label='Iteración Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, iteracion_mejor_costo, width, label='Iteración Mejor Costo', color=light_orange_hex)

# Configurar etiquetas y título
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Número de Iteraciones', fontsize=14)
ax.set_title('Iteración de Convergencia vs Iteración de Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Establecer los límites del eje y
ax.set_ylim(0, 100)

# Añadir líneas horizontales para los promedios con mayor grosor
ax.axhline(y=promedio_iteracion_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Iteración Convergencia')
ax.axhline(y=promedio_iteracion_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Iteración Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Los dos graficos a continuacion representan datos de ESCENARIO 20 NODOS ACO CON DRON

# %%
import matplotlib.pyplot as plt
import numpy as np
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro
# Data provided by the user

costo_convergencia = [
   
81.31829402,
77.17238977,
75.69408327,
75.59266017,
77.81134911,
79.84295433,
78.72986817,
70.89194768,
71.99506456,
77.26134592
]


mejor_costo = [
79.52962036,
77.17238977,
75.69408327,
75.59266017,
77.81134911,
79.84295433,
78.72986817,
70.89194768,
71.99506456,
77.26134592
]
# Calcular los promedios
promedio_costo_convergencia = np.mean(costo_convergencia)
promedio_mejor_costo = np.mean(mejor_costo)
# Labels for the x-axis
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Create a bar chart
fig, ax = plt.subplots(figsize=(15, 8))

# Set the width for better spacing
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, costo_convergencia, width, label='Costo Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, mejor_costo, width, label='Mejor Costo', color=light_orange_hex)

# Set labels and title
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Costo', fontsize=14)
ax.set_title('Costo de Convergencia vs Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Set y-axis limits to display from 20 to 50
ax.set_ylim(65, 85)

# Add the horizontal lines for averages with increased thickness
ax.axhline(y=promedio_costo_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Costo Convergencia')
ax.axhline(y=promedio_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define los códigos de color HEX para naranja oscuro y naranja claro
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro

# Datos proporcionados por el usuario para las iteraciones
iteracion_convergencia = [9,4,6,4,15,6,15,4,64,12]
iteracion_mejor_costo = [57,4,6,4,15,6,15,4,64,12]

# Calcular los promedios
promedio_iteracion_convergencia = np.mean(iteracion_convergencia)
promedio_iteracion_mejor_costo = np.mean(iteracion_mejor_costo)

# Etiquetas para el eje x
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Crear un gráfico de barras
fig, ax = plt.subplots(figsize=(15, 8))

# Establecer el ancho para un mejor espaciado
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, iteracion_convergencia, width, label='Iteración Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, iteracion_mejor_costo, width, label='Iteración Mejor Costo', color=light_orange_hex)

# Configurar etiquetas y título
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Número de Iteraciones', fontsize=14)
ax.set_title('Iteración de Convergencia vs Iteración de Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Establecer los límites del eje y
ax.set_ylim(0, 100)

# Añadir líneas horizontales para los promedios con mayor grosor
ax.axhline(y=promedio_iteracion_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Iteración Convergencia')
ax.axhline(y=promedio_iteracion_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Iteración Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Los dos graficos a continuacion representan datos de ESCENARIO 30 NODOS ACO CON DRON

# %%
import matplotlib.pyplot as plt
import numpy as np
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro
# Data provided by the user



costo_convergencia = [
   
132.3706623,
133.6562466,
132.0698907,
130.9464883,
133.9842448,
134.015109,
131.2473574,
135.0338314,
134.5342757,
125.9302539

]


mejor_costo = [
130.8296482,
133.5904337,
131.8587583,
130.4023561,
133.9842448,
134.015109,
131.2473574,
135.0338314,
134.3289848,
125.3670502

]
# Calcular los promedios
promedio_costo_convergencia = np.mean(costo_convergencia)
promedio_mejor_costo = np.mean(mejor_costo)
# Labels for the x-axis
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Create a bar chart
fig, ax = plt.subplots(figsize=(15, 8))

# Set the width for better spacing
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, costo_convergencia, width, label='Costo Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, mejor_costo, width, label='Mejor Costo', color=light_orange_hex)

# Set labels and title
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Costo', fontsize=14)
ax.set_title('Costo de Convergencia vs Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Set y-axis limits to display from 20 to 50
ax.set_ylim(122.5, 140)

# Add the horizontal lines for averages with increased thickness
ax.axhline(y=promedio_costo_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Costo Convergencia')
ax.axhline(y=promedio_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define los códigos de color HEX para naranja oscuro y naranja claro
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro

# Datos proporcionados por el usuario para las iteraciones
iteracion_convergencia = [14,29,46,23,24,42,46,41,34,50]
iteracion_mejor_costo = [75,46,62,38,24,42,46,41,65,65]

# Calcular los promedios
promedio_iteracion_convergencia = np.mean(iteracion_convergencia)
promedio_iteracion_mejor_costo = np.mean(iteracion_mejor_costo)

# Etiquetas para el eje x
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Crear un gráfico de barras
fig, ax = plt.subplots(figsize=(15, 8))

# Establecer el ancho para un mejor espaciado
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, iteracion_convergencia, width, label='Iteración Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, iteracion_mejor_costo, width, label='Iteración Mejor Costo', color=light_orange_hex)

# Configurar etiquetas y título
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Número de Iteraciones', fontsize=14)
ax.set_title('Iteración de Convergencia vs Iteración de Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Establecer los límites del eje y
ax.set_ylim(0, 100)

# Añadir líneas horizontales para los promedios con mayor grosor
ax.axhline(y=promedio_iteracion_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Iteración Convergencia')
ax.axhline(y=promedio_iteracion_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Iteración Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Los dos graficos a continuacion representan datos de ESCENARIO 10 NODOS MAX_MIN SIN DRON

# %%
import matplotlib.pyplot as plt
import numpy as np
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro
# Data provided by the user
costo_convergencia = [
   
49.330,
48.560,
48.560,
48.986,
49.890,
48.986,
48.904,
48.904,
48.560,
48.904


]


mejor_costo = [
48.986,
48.560,
48.560,
48.560,
48.560,
48.986,
48.560,
48.904,
48.560,
48.904


]
# Calcular los promedios
promedio_costo_convergencia = np.mean(costo_convergencia)
promedio_mejor_costo = np.mean(mejor_costo)
# Labels for the x-axis
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Create a bar chart
fig, ax = plt.subplots(figsize=(15, 8))

# Set the width for better spacing
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, costo_convergencia, width, label='Costo Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, mejor_costo, width, label='Mejor Costo', color=light_orange_hex)

# Set labels and title
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Costo', fontsize=14)
ax.set_title('Costo de Convergencia vs Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Set y-axis limits to display from 20 to 50
ax.set_ylim(48, 50)

# Add the horizontal lines for averages with increased thickness
ax.axhline(y=promedio_costo_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Costo Convergencia')
ax.axhline(y=promedio_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define los códigos de color HEX para naranja oscuro y naranja claro
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro

# Datos proporcionados por el usuario para las iteraciones
iteracion_convergencia = [11,41,9,9,4,41,39,12,12,2]
iteracion_mejor_costo = [57,41,9,57,47,41,62,12,12,2]

# Calcular los promedios
promedio_iteracion_convergencia = np.mean(iteracion_convergencia)
promedio_iteracion_mejor_costo = np.mean(iteracion_mejor_costo)

# Etiquetas para el eje x
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Crear un gráfico de barras
fig, ax = plt.subplots(figsize=(15, 8))

# Establecer el ancho para un mejor espaciado
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, iteracion_convergencia, width, label='Iteración Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, iteracion_mejor_costo, width, label='Iteración Mejor Costo', color=light_orange_hex)

# Configurar etiquetas y título
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Número de Iteraciones', fontsize=14)
ax.set_title('Iteración de Convergencia vs Iteración de Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Establecer los límites del eje y
ax.set_ylim(0, 100)

# Añadir líneas horizontales para los promedios con mayor grosor
ax.axhline(y=promedio_iteracion_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Iteración Convergencia')
ax.axhline(y=promedio_iteracion_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Iteración Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Los dos graficos a continuacion representan datos de ESCENARIO 20 NODOS MAX_MIN SIN DRON

# %%
import matplotlib.pyplot as plt
import numpy as np
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro
# Data provided by the user
costo_convergencia = [
97.892,
100.666,
89.380,
92.593,
94.653,
97.749,
95.996,
99.731,
97.523,
97.102

]


mejor_costo = [
97.237,
100.322,
89.380,
92.593,
94.653,
97.749,
93.932,
94.068,
96.669,
97.102

]
# Calcular los promedios
promedio_costo_convergencia = np.mean(costo_convergencia)
promedio_mejor_costo = np.mean(mejor_costo)
# Labels for the x-axis
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Create a bar chart
fig, ax = plt.subplots(figsize=(15, 8))

# Set the width for better spacing
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, costo_convergencia, width, label='Costo Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, mejor_costo, width, label='Mejor Costo', color=light_orange_hex)

# Set labels and title
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Costo', fontsize=14)
ax.set_title('Costo de Convergencia vs Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Set y-axis limits to display from 20 to 50
ax.set_ylim(80, 110)

# Add the horizontal lines for averages with increased thickness
ax.axhline(y=promedio_costo_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Costo Convergencia')
ax.axhline(y=promedio_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define los códigos de color HEX para naranja oscuro y naranja claro
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro

# Datos proporcionados por el usuario para las iteraciones
iteracion_convergencia = [33,9,4,22,16,3,45,3,12,10]
iteracion_mejor_costo = [79,45,4,22,16,3,76,66,88,10]

# Calcular los promedios
promedio_iteracion_convergencia = np.mean(iteracion_convergencia)
promedio_iteracion_mejor_costo = np.mean(iteracion_mejor_costo)

# Etiquetas para el eje x
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Crear un gráfico de barras
fig, ax = plt.subplots(figsize=(15, 8))

# Establecer el ancho para un mejor espaciado
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, iteracion_convergencia, width, label='Iteración Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, iteracion_mejor_costo, width, label='Iteración Mejor Costo', color=light_orange_hex)

# Configurar etiquetas y título
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Número de Iteraciones', fontsize=14)
ax.set_title('Iteración de Convergencia vs Iteración de Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Establecer los límites del eje y
ax.set_ylim(0, 110)

# Añadir líneas horizontales para los promedios con mayor grosor
ax.axhline(y=promedio_iteracion_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Iteración Convergencia')
ax.axhline(y=promedio_iteracion_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Iteración Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Los dos graficos a continuacion representan datos de ESCENARIO 30 NODOS MAX_MIN SIN DRON

# %%
import matplotlib.pyplot as plt
import numpy as np
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro
# Data provided by the user
costo_convergencia = [
142.291,
142.398,
142.264,
142.713,
143.219,
139.008,
140.452,
144.252,
146.463,
144.484

]


mejor_costo = [
138.878,
141.467,
142.264,
142.713,
143.219,
139.008,
138.630,
142.166,
140.886,
139.622


]
# Calcular los promedios
promedio_costo_convergencia = np.mean(costo_convergencia)
promedio_mejor_costo = np.mean(mejor_costo)
# Labels for the x-axis
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Create a bar chart
fig, ax = plt.subplots(figsize=(15, 8))

# Set the width for better spacing
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, costo_convergencia, width, label='Costo Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, mejor_costo, width, label='Mejor Costo', color=light_orange_hex)

# Set labels and title
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Costo', fontsize=14)
ax.set_title('Costo de Convergencia vs Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Set y-axis limits to display from 20 to 50
ax.set_ylim(135, 150)

# Add the horizontal lines for averages with increased thickness
ax.axhline(y=promedio_costo_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Costo Convergencia')
ax.axhline(y=promedio_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define los códigos de color HEX para naranja oscuro y naranja claro
dark_orange_hex = '#FF8C00'  # Naranja oscuro
light_orange_hex = '#FFA07A'  # Naranja claro

# Datos proporcionados por el usuario para las iteraciones
iteracion_convergencia = [19,8,5,6,44,11,7,22,5,17]
iteracion_mejor_costo = [99,39,5,6,44,11,98,65,64,84]

# Calcular los promedios
promedio_iteracion_convergencia = np.mean(iteracion_convergencia)
promedio_iteracion_mejor_costo = np.mean(iteracion_mejor_costo)

# Etiquetas para el eje x
ejecuciones = ['E' + str(i) for i in range(1, 11)]

# Crear un gráfico de barras
fig, ax = plt.subplots(figsize=(15, 8))

# Establecer el ancho para un mejor espaciado
width = 0.35

bars1 = ax.bar(np.arange(len(ejecuciones)) - width/2, iteracion_convergencia, width, label='Iteración Convergencia', color=dark_orange_hex)
bars2 = ax.bar(np.arange(len(ejecuciones)) + width/2, iteracion_mejor_costo, width, label='Iteración Mejor Costo', color=light_orange_hex)

# Configurar etiquetas y título
ax.set_xlabel('Ejecuciones', fontsize=14)
ax.set_ylabel('Número de Iteraciones', fontsize=14)
ax.set_title('Iteración de Convergencia vs Iteración de Mejor Costo', fontsize=16)
ax.set_xticks(np.arange(len(ejecuciones)))
ax.set_xticklabels(ejecuciones, fontsize=12)

# Establecer los límites del eje y
ax.set_ylim(0, 110)

# Añadir líneas horizontales para los promedios con mayor grosor
ax.axhline(y=promedio_iteracion_convergencia, color='red', linestyle='-', linewidth=2, label='Promedio Iteración Convergencia')
ax.axhline(y=promedio_iteracion_mejor_costo, color='blue', linestyle='-', linewidth=2, label='Promedio Iteración Mejor Costo')

# Añadir la leyenda y colocarla en la parte superior derecha
ax.legend(fontsize=12, loc='upper right')

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos proporcionados para el gráfico de barras
promedios_con_dron = {'Costo de Convergencia': 129.257, 'Mejor Costo': 127.807}
promedios_sin_dron = {'Costo de Convergencia': 132.379, 'Mejor Costo': 132.066}

# Etiquetas para el eje x
categorias = list(promedios_con_dron.keys())

# Valores para el eje y
valores_con_dron = list(promedios_con_dron.values())
valores_sin_dron = list(promedios_sin_dron.values())

# Posiciones de las barras en el eje x
x = np.arange(len(categorias))

# Ancho de las barras
width = 0.35

# Crear el gráfico de barras
fig, ax = plt.subplots(figsize=(10, 6))

# Definir las barras
barras_con_dron = ax.bar(x - width/2, valores_con_dron, width, label='MMAS', color='blue')
barras_sin_dron = ax.bar(x + width/2, valores_sin_dron, width, label='ACO', color='orange')

# Añadir etiquetas y título
ax.set_xlabel('Categorías')
ax.set_ylabel('Valores Promedio')
ax.set_title('Comparación de Costos entre MMAS y ACO')
ax.set_xticks(x)
ax.set_xticklabels(categorias)

# Ajustar los rangos del eje y según se requiera
ax.set_ylim([100, 140])  # Por ejemplo, de 0 a 80

# Colocar la leyenda en la parte superior derecha
ax.legend(loc='upper right')

# Mostrar el gráfico
plt.show()
